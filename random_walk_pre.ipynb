# %%
function line_random_walk(n)
    current=0
    for i=1:n
        rng=rand(1:2)
        if rng==1
            current +=1
        else
            current -=1
        end 
    end
    return current
end
# Out:
# line_random_walk (generic function with 1 method)

# %%
function loop_through_random_walk(func,steps,times)
    array=[]
    for i=1:times
        array=push!(array,func(steps))
    end
    return array
end
# Out:
# loop_through_random_walk (generic function with 1 method)

# %%
using Plots

# %%
arr=loop_through_random_walk(line_random_walk,1000,50000)
# Out:
# 50000-element Array{Any,1}:
#  -24
#  -14
#  -10
#  -22
#   28
#   50
#  -20
#   40
#  -38
#   46
#   14
#  -40
#    8
#    ⋮
#  -12
#   18
#   -2
#   22
#  -24
#   12
#  -50
#   44
#   12
#  -20
#   44
#   -8

# %%
histogram(arr)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 42.5104,375.869 580.315,375.869 580.315,11.811 42.5104,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4202">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   117.421,375.869 117.421,11.811
#   "/>
# ...

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
histogram(arr)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 42.5104,375.869 580.315,375.869 580.315,11.811 42.5104,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4402">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   117.421,375.869 117.421,11.811
#   "/>
# ...
